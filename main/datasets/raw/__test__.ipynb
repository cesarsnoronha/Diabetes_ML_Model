# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("diabetes_binary_5050split_health_indicators_BRFSS2015.csv", low_memory=False)
df.shape
# Out:
# (70692, 22)

# %%
df.sample(5)
# Out:
#        Diabetes_binary  HighBP  HighChol  CholCheck   BMI  Smoker  Stroke  \
# 13349              0.0     0.0       1.0        1.0  28.0     0.0     0.0
# 6950               0.0     0.0       0.0        1.0  23.0     0.0     0.0
# 46445              1.0     1.0       1.0        1.0  35.0     1.0     0.0
# 14892              0.0     0.0       0.0        1.0  29.0     1.0     0.0
# 36810              1.0     1.0       1.0        1.0  29.0     1.0     0.0
#
#        HeartDiseaseorAttack  PhysActivity  Fruits  ...  AnyHealthcare  \
# 13349                   0.0           0.0     1.0  ...            1.0
# 6950                    0.0           1.0     0.0  ...            1.0
# 46445                   0.0           1.0     0.0  ...            1.0
# 14892                   0.0           0.0     0.0  ...            1.0
# 36810                   0.0           0.0     1.0  ...            1.0
#
#        NoDocbcCost  GenHlth  MentHlth  PhysHlth  DiffWalk  Sex   Age  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70692 entries, 0 to 70691
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Diabetes_binary       70692 non-null  float64
#  1   HighBP                70692 non-null  float64
#  2   HighChol              70692 non-null  float64
#  3   CholCheck             70692 non-null  float64
#  4   BMI                   70692 non-null  float64
#  5   Smoker                70692 non-null  float64
#  6   Stroke                70692 non-null  float64
#  7   HeartDiseaseorAttack  70692 non-null  float64
#  8   PhysActivity          70692 non-null  float64
#  9   Fruits                70692 non-null  float64
#  10  Veggies               70692 non-null  float64
#  11  HvyAlcoholConsump     70692 non-null  float64
#  12  AnyHealthcare         70692 non-null  float64
#  13  NoDocbcCost           70692 non-null  float64
# ...

# %%
df.corr()
# Out:
#                       Diabetes_binary    HighBP  HighChol  CholCheck  \
# Diabetes_binary              1.000000  0.381516  0.289213   0.115382
# HighBP                       0.381516  1.000000  0.316515   0.103283
# HighChol                     0.289213  0.316515  1.000000   0.085981
# CholCheck                    0.115382  0.103283  0.085981   1.000000
# BMI                          0.293373  0.241019  0.131309   0.045648
# Smoker                       0.085999  0.087438  0.093398  -0.004331
# Stroke                       0.125427  0.129060  0.099786   0.022529
# HeartDiseaseorAttack         0.211523  0.210750  0.181187   0.043497
# PhysActivity                -0.158666 -0.136102 -0.090453  -0.008249
# Fruits                      -0.054077 -0.040852 -0.047384   0.017384
# Veggies                     -0.079293 -0.066624 -0.042836   0.000349
# HvyAlcoholConsump           -0.094853 -0.027030 -0.025443  -0.027146
# AnyHealthcare                0.023191  0.035764  0.031532   0.106800
# ...

# %%
df2 = df.drop(['Sex', 'NoDocbcCost'], axis=1).sample(10000)
df2
# Out:
#        Diabetes_binary  HighBP  HighChol  CholCheck   BMI  Smoker  Stroke  \
# 44033              1.0     1.0       1.0        1.0  51.0     1.0     0.0
# 69397              1.0     1.0       1.0        1.0  26.0     1.0     0.0
# 11342              0.0     0.0       0.0        1.0  32.0     1.0     0.0
# 51575              1.0     0.0       0.0        1.0  30.0     0.0     0.0
# 63432              1.0     1.0       1.0        1.0  30.0     0.0     0.0
# ...                ...     ...       ...        ...   ...     ...     ...
# 35471              1.0     1.0       1.0        1.0  27.0     1.0     0.0
# 68136              1.0     1.0       1.0        1.0  31.0     0.0     0.0
# 43069              1.0     1.0       1.0        1.0  37.0     0.0     0.0
# 44488              1.0     1.0       1.0        1.0  33.0     0.0     0.0
# 24221              0.0     1.0       1.0        1.0  27.0     0.0     0.0
#
#        HeartDiseaseorAttack  PhysActivity  Fruits  Veggies  HvyAlcoholConsump  \
# ...

# %%
#df2.value_counts()#.plot(kind='bar',subplots=True, layout=(1,2))
df2['Diabetes_binary'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df2.columns
# Out:
# Index(['Diabetes_binary', 'HighBP', 'HighChol', 'CholCheck', 'BMI', 'Smoker',
#        'Stroke', 'HeartDiseaseorAttack', 'PhysActivity', 'Fruits', 'Veggies',
#        'HvyAlcoholConsump', 'AnyHealthcare', 'GenHlth', 'MentHlth', 'PhysHlth',
#        'DiffWalk', 'Age', 'Education', 'Income'],
#       dtype='object')

# %%
fig, axs = plt.subplots(nrows=5, ncols=4, figsize=(16, 18))
plt.subplots_adjust(hspace=0.5 ,wspace=0.3)
fig.suptitle("Observando no geral o comportamento de cada coluna", fontsize=18, y=0.95)

# loop through columns
for column, ax in zip(df2.columns, axs.ravel()):
    df2[column].value_counts().plot(kind='bar',ax=ax)

    # chart formatting
    ax.set_title(column.upper())
    #ax.get_legend().remove()
    ax.set_xlabel("")

plt.show()

# %%
Diabetes = df[df['Diabetes_binary'] == 1]
No_Diabetes = df[df['Diabetes_binary'] == 0]

df1 = Diabetes[['HighBP']].value_counts().reset_index()
df2 = No_Diabetes[['HighBP']].value_counts().reset_index()

df1.columns = ['HighBP', 'Count']
df2.columns = ['HighBP', 'Count']

result = pd.DataFrame({
    "High_BP":[df1.iloc[0].Count, df2.iloc[0].Count],
    "Low_BP":[df1.iloc[1].Count, df2.iloc[1].Count]
    }, 
    index=["Diabetes", "No_Diabetes"]
)
result.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
column = "HighBP"

df1 = Diabetes[[column]].value_counts().reset_index()
df1
# Out:
#    HighBP      0
# 0     1.0  26604
# 1     0.0   8742

# %%
column = "DiffWalk"

df1 = Diabetes[[column]].value_counts().reset_index()
df1
# Out:
#    DiffWalk      0
# 0       0.0  22225
# 1       1.0  13121

# %%
column = "HighBP"

df1 = Diabetes[[column]].value_counts().reset_index()
df2 = No_Diabetes[[column]].value_counts().reset_index()

df1.columns = [column, 'Count']
df2.columns = [column, 'Count']

txt = "No_{0}".format(column)
    
result = pd.DataFrame({
    column:[df1.iloc[0].Count, df2.iloc[0].Count],
    txt:[df1.iloc[1].Count, df2.iloc[1].Count]
    }, 
    index=["Diabetes", "No_Diabetes"]
)
result.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
Diabetes = df[df['Diabetes_binary'] == 1]
No_Diabetes = df[df['Diabetes_binary'] == 0]

#colunas com correlação negativa e positiva
PositivaCorr = [ 'HighBP', 'HighChol', 'BMI', 'HeartDiseaseorAttack', 'GenHlth', 'PhysHlth', 'DiffWalk', 'Age']
NegativaCorr = [ 'PhysActivity', 'Fruits', 'Veggies', 'HvyAlcoholConsump', 'Education', 'Income']
# Out:
# Index(['Diabetes_binary', 'HighBP', 'HighChol', 'BMI', 'HeartDiseaseorAttack',
#        'GenHlth', 'PhysHlth', 'DiffWalk', 'Age'],
#       dtype='object')

# %%
fig, axs = plt.subplots(nrows=4, ncols=2, figsize=(12, 12))
plt.subplots_adjust(hspace=0.5 ,wspace=0.3)
fig.suptitle("gráficos com correlação positiva com diabetes pela presença de Diabetes", fontsize=18, y=0.95)


for column, ax in zip(PositivaCorr, axs.ravel()):
    df1 = Diabetes[[column]].value_counts().reset_index()
    df2 = No_Diabetes[[column]].value_counts().reset_index()

    df1.columns = [column, 'Count']
    df2.columns = [column, 'Count']

    txt = "No_{0}".format(column)
    
    result = pd.DataFrame({
        column:[df1.iloc[0].Count, df2.iloc[0].Count],
        txt:[df1.iloc[1].Count, df2.iloc[1].Count]
        }, 
        index=["Diabetes", "No_Diabetes"]
    )
    result.plot(kind='bar',ax=ax,alpha=0.75, rot=0)
    
    
    # chart formatting
    ax.set_title(column.upper())
    #ax.get_legend().remove()
    ax.set_xlabel("")

plt.show()

# %%
#Divisão do dataset
train_input, test_input, train_target, test_target = train_test_split(breast_data.data, breast_data.target, test_size=0.4)

#Gerenciamento dos modelos
models = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(),
    "Decision Tree": DecisionTreeClassifier(),
    "KNN": KNeighborsClassifier(), 
    "SVM": SVC(),
}
#Declara modelo de normalização
scaler = StandardScaler()

for model_name, model_obj in models.items():
    #Pipeline de dados aonde a normalização é feita
    model = Pipeline([ # Isso aqui é muito importante
        ("Scaler", scaler), # Coloca a normalização no modelo
        ("Model", model_obj) # Coloca o modelo de ML no modelo
    ])
    #Treinamento e teste dos modelos
    model.fit(train_input, train_target) #passa os dados pelo modelo
    model_score = model.score(test_input, test_target)

    print(f"{model_name}: {model_score:.02f}")
